# %% [raw]
# Title: json file
# Author: Hassan

# %%
import json

# %%
# set the hyperparameters for the model
hyper_param = {
    "batch_size": 256,
    "num_epochs": 16,
    "conv1d_filters": 128,
    "conv1d_kernel_size": 15,
    "conv2d_filters": 128,
    "conv2d_kernel_size": (15,15),
    "strides": 5,
    "dense_units": 10,
    "dropout_rate": 0.2,
}

# save hyperparameters to a JSON file
with open('/home/hhousseinho/MIAT/Documents/Srna_Classification/Data/hyperparameters_model.json', 'w') as f:
    json.dump(hyper_param, f)  #to convert Python dictionary to JSON format

# %%
# set the data directory
data_directory = {
   "SNORD_RFAM" : "/home/hhousseinho/MIAT/Documents/Srna_Classification/RNAfold/SNORD_RFAM",
   "TRNA_RFAM_Reducted" : "/home/hhousseinho/MIAT/Documents/Srna_Classification/RNAfold/TRNA_RFAM_Reducted",
    
   "SNORD_RFAM.fasta" : "/home/hhousseinho/MIAT/Documents/Srna_Classification/Data/SNORD_RFAM.fasta",
   "TRNA_RFAM_Reducted.fasta" : "/home/hhousseinho/MIAT/Documents/Srna_Classification/Data/TRNA_RFAM_Reducted.fasta",
    
   "SNORD_RFAM.fasta.gz" : "/home/hhousseinho/MIAT/Documents/Srna_Classification/Data/SNORD_RFAM.fasta.gz",
   "TRNA_RFAM_Reducted.fasta.gz" : "/home/hhousseinho/MIAT/Documents/Srna_Classification/Data/TRNA_RFAM_Reducted.fasta.gz"


}

# save hyperparameters to a JSON file
with open('/home/hhousseinho/MIAT/Documents/Srna_Classification/Data/data_directory.json', 'w') as f:
    json.dump(data_directory, f)  #to convert Python dictionary to JSON format
