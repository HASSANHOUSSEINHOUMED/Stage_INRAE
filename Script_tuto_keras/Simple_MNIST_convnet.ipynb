# %% [raw]
# Title: Simple MNIST convnet
# Author: [fchollet](https://twitter.com/fchollet)
# Date created: 2015/06/19
# Last modified: 2020/04/21
# Description: A simple convnet that achieves ~99% test accuracy on MNIST.
# Accelerator: GPU

# %%
## Setup

import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %% [raw]
# ## Prepare the data

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# %%
# Load the data and split it between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

# %%
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# Out:
# x_train shape: (60000, 28, 28, 1, 1, 1, 1)
# 60000 train samples
# 10000 test samples

# %%
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
## Build the model

model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_1 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model

batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# 2023-02-14 13:42:26.433086: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 161.50MiB (rounded to 169344000)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-02-14 13:42:26.433163: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-02-14 13:42:26.433205: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 20, Chunks in use: 20. 5.0KiB allocated for chunks. 5.0KiB in use in bin. 912B client-requested in use in bin.
# 2023-02-14 13:42:26.433242: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433254: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 4, Chunks in use: 3. 5.2KiB allocated for chunks. 3.8KiB in use in bin. 3.3KiB client-requested in use in bin.
# 2023-02-14 13:42:26.433261: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433270: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433277: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433285: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433297: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 2, Chunks in use: 1. 125.0KiB allocated for chunks. 62.5KiB in use in bin. 62.5KiB client-requested in use in bin.
# 2023-02-14 13:42:26.433310: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 4, Chunks in use: 3. 293.8KiB allocated for chunks. 221.8KiB in use in bin. 206.5KiB client-requested in use in bin.
# 2023-02-14 13:42:26.433318: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433323: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433328: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433333: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.46MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433338: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433343: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433348: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433353: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433357: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433362: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433367: I
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [14], in <cell line: 8>()
#       4 epochs = 15
#       6 model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
# ----> 8 model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433375: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:42:26.433382: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 161.50MiB was 128.00MiB, Chunk State:
# 2023-02-14 13:42:26.433389: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 1968128
# 2023-02-14 13:42:26.433400: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400000 of size 256 next 1
# 2023-02-14 13:42:26.433404: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400100 of size 1280 next 2
# 2023-02-14 13:42:26.433409: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400600 of size 256 next 3
# 2023-02-14 13:42:26.433413: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400700 of size 256 next 4
# 2023-02-14 13:42:26.433417: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400800 of size 256 next 6
# 2023-02-14 13:42:26.433421: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400900 of size 256 next 7
# 2023-02-14 13:42:26.433424: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400a00 of size 256 next 5
# 2023-02-14 13:42:26.433428: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400b00 of size 256 next 8
# 2023-02-14 13:42:26.433432: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400c00 of size 256 next 13
# 2023-02-14 13:42:26.433436: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400d00 of size 256 next 11
# 2023-02-14 13:42:26.433440: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400e00 of size 256 next 12
# 2023-02-14 13:42:26.433444: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400f00 of size 256 next 18
# 2023-02-14 13:42:26.433448: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401000 of size 256 next 20
# 2023-02-14 13:42:26.433452: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401100 of size 256 next 16
# 2023-02-14 13:42:26.433456: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401200 of size 256 next 17
# 2023-02-14 13:42:26.433460: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401300 of size 256 next 25
# 2023-02-14 13:42:26.433464: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401400 of size 256 next 9
# 2023-02-14 13:42:26.433468: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401500 of size 1280 next 10
# 2023-02-14 13:42:26.433472: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401a00 of size 256 next 27
# 2023-02-14 13:42:26.433476: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401b00 of size 256 next 28
# 2023-02-14 13:42:26.433480: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401c00 of size 256 next 29
# 2023-02-14 13:42:26.433484: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401d00 of size 256 next 30
# 2023-02-14 13:42:26.433487: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e401e00 of size 1536 next 22
# 2023-02-14 13:42:26.433491: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e402400 of size 1280 next 21
# 2023-02-14 13:42:26.433495: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e402900 of size 64000 next 26
# 2023-02-14 13:42:26.433500: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e412300 of size 79616 next 15
# 2023-02-14 13:42:26.433504: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e425a00 of size 73728 next 14
# 2023-02-14 13:42:26.433508: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e437a00 of size 64000 next 19
# 2023-02-14 13:42:26.433512: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e447400 of size 73728 next 24
# 2023-02-14 13:42:26.433517: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e459400 of size 73728 next 23
# 2023-02-14 13:42:26.433522: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e46b400 of size 1528832 next 18446744073709551615
# 2023-02-14 13:42:26.433527: I tensorflow/tsl/framework/bfc_allocator.cc:1095]      Summary of in-use Chunks by size:
# 2023-02-14 13:42:26.433546: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 20 Chunks of size 256 totalling 5.0KiB
# 2023-02-14 13:42:26.433551: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 1280 totalling 3.8KiB
# 2023-02-14 13:42:26.433556: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 64000 totalling 62.5KiB
# 2023-02-14 13:42:26.433561: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 73728 totalling 144.0KiB
# 2023-02-14 13:42:26.433565: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 79616 totalling 77.8KiB
# 2023-02-14 13:42:26.433570: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 293.0KiB
# 2023-02-14 13:42:26.433575: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 1968128 memory_limit_: 10616832 available bytes: 8648704 curr_region_allocation_bytes_: 21233664
# 2023-02-14 13:42:26.433583: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                        10616832
# InUse:                          300032
# MaxInUse:                       436480
# NumAllocs:                          57
# MaxAllocSize:                   143616
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-02-14 13:42:26.433591: W tensorflow/tsl/framework/bfc_allocator.cc:492] *__************___*****_____________________________________________________________________________

# %%
## Evaluate the trained model

score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 2023-02-14 13:43:35.330765: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 29.91MiB (rounded to 31360000)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-02-14 13:43:35.330816: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-02-14 13:43:35.330838: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 18, Chunks in use: 15. 4.5KiB allocated for chunks. 3.8KiB in use in bin. 480B client-requested in use in bin.
# 2023-02-14 13:43:35.330855: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330872: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 4, Chunks in use: 2. 5.8KiB allocated for chunks. 2.5KiB in use in bin. 2.1KiB client-requested in use in bin.
# 2023-02-14 13:43:35.330886: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330900: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330914: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330928: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330943: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 1, Chunks in use: 0. 62.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330961: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 2, Chunks in use: 2. 149.8KiB allocated for chunks. 149.8KiB in use in bin. 134.5KiB client-requested in use in bin.
# 2023-02-14 13:43:35.330977: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 1, Chunks in use: 0. 206.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.330991: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331005: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331019: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.46MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331034: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331048: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331061: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331075: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331090: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331103: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       1 ## Evaluate the trained model
# ----> 3 score = model.evaluate(x_test, y_test, verbose=0)
#       4 print("Test loss:", score[0])
#       5 print("Test accuracy:", score[1])
#
# File ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331117: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331136: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-02-14 13:43:35.331154: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 29.91MiB was 16.00MiB, Chunk State:
# 2023-02-14 13:43:35.331167: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 1968128
# 2023-02-14 13:43:35.331185: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400000 of size 256 next 1
# 2023-02-14 13:43:35.331198: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400100 of size 1280 next 2
# 2023-02-14 13:43:35.331210: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400600 of size 256 next 3
# 2023-02-14 13:43:35.331222: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400700 of size 256 next 4
# 2023-02-14 13:43:35.331234: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400800 of size 256 next 6
# 2023-02-14 13:43:35.331246: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e400900 of size 256 next 7
# 2023-02-14 13:43:35.331257: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400a00 of size 256 next 5
# 2023-02-14 13:43:35.331269: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400b00 of size 256 next 8
# 2023-02-14 13:43:35.331281: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e400c00 of size 256 next 13
# 2023-02-14 13:43:35.331293: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400d00 of size 256 next 11
# 2023-02-14 13:43:35.331305: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e400e00 of size 256 next 12
# 2023-02-14 13:43:35.331317: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e400f00 of size 256 next 18
# 2023-02-14 13:43:35.331329: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401000 of size 256 next 20
# 2023-02-14 13:43:35.331341: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401100 of size 256 next 16
# 2023-02-14 13:43:35.331353: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401200 of size 256 next 17
# 2023-02-14 13:43:35.331365: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401300 of size 256 next 25
# 2023-02-14 13:43:35.331377: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e401400 of size 1792 next 27
# 2023-02-14 13:43:35.331389: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401b00 of size 256 next 28
# 2023-02-14 13:43:35.331401: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401c00 of size 256 next 29
# 2023-02-14 13:43:35.331413: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e401d00 of size 256 next 30
# 2023-02-14 13:43:35.331425: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e401e00 of size 1536 next 22
# 2023-02-14 13:43:35.331437: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e402400 of size 1280 next 21
# 2023-02-14 13:43:35.331449: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e402900 of size 64000 next 26
# 2023-02-14 13:43:35.331462: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e412300 of size 79616 next 15
# 2023-02-14 13:43:35.331474: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e425a00 of size 211456 next 24
# 2023-02-14 13:43:35.331487: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7f4d5e459400 of size 73728 next 23
# 2023-02-14 13:43:35.331499: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7f4d5e46b400 of size 1528832 next 18446744073709551615
# 2023-02-14 13:43:35.331513: I tensorflow/tsl/framework/bfc_allocator.cc:1095]      Summary of in-use Chunks by size:
# 2023-02-14 13:43:35.331528: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 15 Chunks of size 256 totalling 3.8KiB
# 2023-02-14 13:43:35.331543: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 1280 totalling 2.5KiB
# 2023-02-14 13:43:35.331557: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 73728 totalling 72.0KiB
# 2023-02-14 13:43:35.331572: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 79616 totalling 77.8KiB
# 2023-02-14 13:43:35.331585: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 156.0KiB
# 2023-02-14 13:43:35.331599: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 1968128 memory_limit_: 10616832 available bytes: 8648704 curr_region_allocation_bytes_: 21233664
# 2023-02-14 13:43:35.331618: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                        10616832
# InUse:                          159744
# MaxInUse:                       436480
# NumAllocs:                          57
# MaxAllocSize:                   143616
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-02-14 13:43:35.331635: W tensorflow/tsl/framework/bfc_allocator.cc:492] *__*****__________*****_____________________________________________________________________________
